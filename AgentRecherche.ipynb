# %%
# !/opt/conda/bin/pip install chromadb
# !/opt/conda/bin/pip install sentence_transformers
# !/opt/conda/bin/pip install streamlit pyngrok
# !/opt/conda/bin/pip install plotly==5.24.1
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Defaulting to user installation because normal site-packages is not writeable
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.1/19.1 MB 59.6 MB/s eta 0:00:00a 0:00:01
# ...

# %%
import os
from pyngrok import ngrok
# Arrêter les tunnels ngrok en Python
ngrok.kill()

print("🚫 Tous les tunnels Ngrok ont été arrêtés.")
# Out:
# 🚫 Tous les tunnels Ngrok ont été arrêtés.

# %%
import subprocess
from pyngrok import ngrok

# 🔑 Ajouter le token Ngrok
ngrok.set_auth_token("2sX3FD5EHzo2LWnlzF8I5jnW6Jt_HkEW7pSkzM24MxzVDsUS")

# ✅ Démarrer un tunnel proprement
public_url = ngrok.connect(8501, "http")
print(f"🚀 Ton application Streamlit est accessible ici : {public_url}")

# 🚀 Lancer Streamlit en arrière-plan via le chemin absolu de Python
process = subprocess.Popen(
    ["/opt/conda/bin/python", "-m", "streamlit", "run", "./Legal-Email-Styling-app_dev/app/1_Home.py"],
    stdout=subprocess.PIPE,
    stderr=subprocess.PIPE,
    text=True
)

print("✅ Streamlit a été lancé en arrière-plan.")
# Out:
# 🚀 Ton application Streamlit est accessible ici : NgrokTunnel: "https://20cb-138-195-193-236.ngrok-free.app" -> "http://localhost:8501"
# ✅ Streamlit a été lancé en arrière-plan.
